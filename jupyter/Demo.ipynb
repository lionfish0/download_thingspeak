# %%
from download_thingspeak import download

# %%
data = download('http://thingspeak.com/channels/327840',verbose=True,apikey='[secret]')
# Out:
# Using cache
# Using 84954 records from cache
#     Adding 0 records...
# New cache has 84954 records, saving.

# %%
data
# Out:
# [{'created_at': '2017-09-08T07:24:45Z',
#   'entry_id': 1,
#   'field1': '    8.77',
#   'field2': '   11.69',
#   'field3': '   46.84',
#   'field4': '    1.39',
#   'field5': '0.357654',
#   'field6': '32.584206',
#   'field7': '    3.59'},
#  {'created_at': '2017-09-08T07:25:44Z',
#   'entry_id': 2,
#   'field1': '    9.13',
#   'field2': '   12.27',
#   'field3': '   51.49',
#   'field4': '    1.39',
#   'field5': '0.357743',
#   'field6': '32.584473',
#   'field7': '    3.59'},
#  {'created_at': '2017-09-08T07:26:43Z',
#   'entry_id': 3,
#   'field1': '    9.48',
#   'field2': '   12.78',
#   'field3': '   65.14',
#   'field4': '    1.39',
#   'field5': '0.357653',
#   'field6': '32.584225',
#   'field7': '    3.59'},
#  {'created_at': '2017-09-08T07:27:42Z',
#   'entry_id': 4,
#   'field1': '    9.00',
#   'field2': '   12.20',
#   'field3': '   57.98',
#   'field4': '    1.39',
#   'field5': '0.357728',
#   'field6': '32.584381',
#   'field7': '    3.59'},
# ...
